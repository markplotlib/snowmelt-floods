# %%
2+22
# Out:
# 24

# %%
from rasterio.io import MemoryFile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from rasterio.io import MemoryFile
#
# ModuleNotFoundError: No module named 'rasterio'
